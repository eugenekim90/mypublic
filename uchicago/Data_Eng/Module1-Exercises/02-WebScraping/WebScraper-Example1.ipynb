# %% [markdown]
# #### DATA ENGINEERING PLATFORMS (MSCA 31012)
# #### Webscraping using Python ( Example 1 )
#
# References:
# https://github.com/REMitchell/python-scraping
# https://first-web-scraper.readthedocs.io/en/latest/
# http://web.stanford.edu/~zlotnick/TextAsData/Web_Scraping_with_Beautiful_Soup.html
# http://altitudelabs.com/blog/web-scraping-with-python-and-beautiful-soup/
#
# Installation:
# `pip install BS4`  |
# `pip install Requests`
#
#
# Beautiful Soup is a Python package for parsing HTML and XML documents (including having malformed markup, i.e. non-closed tags, so named after tag soup). It creates a parse tree for parsed pages that can be used to extract data from HTML, which is useful for web scraping.

# %%
# !pip install BS4
# !pip install Requests
# Out:
# Requirement already satisfied: BS4 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from BS4) (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->BS4) (1.9.3)
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/Users/sbharadwaj/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: Requests in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (1.24.2)
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/Users/sbharadwaj/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import csv
import requests
from bs4 import BeautifulSoup
from IPython.display import HTML

# %% [markdown]
# Scraping Rules
# --------------
# - You should check a website’s Terms and Conditions before you scrape it. Be careful to read the statements about legal use of data. Usually, the data you scrape should not be used for commercial purposes.
# - Do not request data from the website too aggressively with your program (also known as spamming), as this may break the website. Make sure your program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# - The layout of a website may change from time to time, so make sure to revisit the site and rewrite your code as needed

# %%
# scrape the current Detainees of Boone County Jail from webpage into CSV
url = 'https://report.boonecountymo.org/mrcjava/servlet/SH01_MP.I00290s'
headers = {'User-Agent': "Chrome/54.0.2840.90"}
response = requests.get(url, headers=headers)
html = response.content

# %%
HTML('<iframe src=http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp width=900 height=350></iframe>')
# Out:
# <iframe src=http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp width=900 height=350></iframe>

# %%
soup = BeautifulSoup(html, "lxml")
table = soup.find('tbody', attrs={'class': 'stripe'})

# %%
tmpRow = (table.findAll('tr')[1:])
print (tmpRow)

# The <tr> tag specifies a row in an HTML table.
# Each table data/cell is defined with a <td> tag.
# Out:
# [<tr class="even">
# <td class="two td_left" data-th="Last Name">AKES</td>
# <td class="two td_left" data-th="First Name">MELANIE</td>
# <td class="two td_left" data-th="Middle Name">LEIGH</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">38</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1845&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">ARMSTEAD</td>
# <td class="one td_left" data-th="First Name">AUGUSTUS</td>
# <td class="one td_left" data-th="Middle Name">ADOLPH</td>
# <td class="one td_left" data-th="Suffix">JR</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">32</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=14107&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">AUNGERER</td>
# <td class="two td_left" data-th="First Name">MARK</td>
# <td class="two td_left" data-th="Middle Name">CHARLES</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">54</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1475&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">AYERS</td>
# <td class="one td_left" data-th="First Name">DANIEL</td>
# <td class="one td_left" data-th="Middle Name">DASHAWN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">18</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=332&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">AYLOR</td>
# <td class="two td_left" data-th="First Name">KENNETH</td>
# <td class="two td_left" data-th="Middle Name">MATTHEW</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">28</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=20753&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BACZEWSKI</td>
# <td class="one td_left" data-th="First Name">ERIC</td>
# <td class="one td_left" data-th="Middle Name">STEVEN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">38</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=27107&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BANKS</td>
# <td class="two td_left" data-th="First Name">TIMOTHY</td>
# <td class="two td_left" data-th="Middle Name">MAURICE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">40</td>
# <td class="two td_left" data-th="City">KANSAS CITY</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=103&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BARFIELD</td>
# <td class="one td_left" data-th="First Name">AARON</td>
# <td class="one td_left" data-th="Middle Name">W</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">39</td>
# <td class="one td_left" data-th="City">ASHLAND</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=25897&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BATISTE</td>
# <td class="two td_left" data-th="First Name">WALTER</td>
# <td class="two td_left" data-th="Middle Name">ALLEN</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">ST.LOUIS</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=350&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BAUCOM</td>
# <td class="one td_left" data-th="First Name">JASON</td>
# <td class="one td_left" data-th="Middle Name">RILEY</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">47</td>
# <td class="one td_left" data-th="City">ROCHEPORT</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1513&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BENNETT</td>
# <td class="two td_left" data-th="First Name">GENTARA</td>
# <td class="two td_left" data-th="Middle Name">LENNA</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">20</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=15648&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BENZ</td>
# <td class="one td_left" data-th="First Name">WILLIAM</td>
# <td class="one td_left" data-th="Middle Name">ERNEST</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">32</td>
# <td class="one td_left" data-th="City">OLATHE</td>
# <td class="one td_left" data-th="State">KS</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3629&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BERARDI</td>
# <td class="two td_left" data-th="First Name">DEBORAH</td>
# <td class="two td_left" data-th="Middle Name">EVA</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">59</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1918&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BERRY</td>
# <td class="one td_left" data-th="First Name">ROBERT</td>
# <td class="one td_left" data-th="Middle Name">JOE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">32</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=172&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BLACKBURN</td>
# <td class="two td_left" data-th="First Name">DAKOTA</td>
# <td class="two td_left" data-th="Middle Name">COLE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">27</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=8794&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BLAGG</td>
# <td class="one td_left" data-th="First Name">SHANE</td>
# <td class="one td_left" data-th="Middle Name">EZRA</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">24</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=15864&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BOLEY</td>
# <td class="two td_left" data-th="First Name">JASON</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">42</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=390&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BONAPARTE</td>
# <td class="one td_left" data-th="First Name">FRANK</td>
# <td class="one td_left" data-th="Middle Name">CORTEZ</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">39</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=156&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BREEDLOVE</td>
# <td class="two td_left" data-th="First Name">WILLIAM</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">58</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=413&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BRINKMAN</td>
# <td class="one td_left" data-th="First Name">STEVEN</td>
# <td class="one td_left" data-th="Middle Name">WAYNE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">44</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2447&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BROOKINS</td>
# <td class="two td_left" data-th="First Name">GARY</td>
# <td class="two td_left" data-th="Middle Name">LARAND</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">63</td>
# <td class="two td_left" data-th="City">MEXICO</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=28201&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BROWN</td>
# <td class="one td_left" data-th="First Name">DWAYNE</td>
# <td class="one td_left" data-th="Middle Name">DEAN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">35</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=11864&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BROWN</td>
# <td class="two td_left" data-th="First Name">FELICIA</td>
# <td class="two td_left" data-th="Middle Name">DAWN</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">29</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2499&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BROWN</td>
# <td class="one td_left" data-th="First Name">MICHAEL</td>
# <td class="one td_left" data-th="Middle Name">JEFFERSON</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">36</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=21144&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BROWN-WELLS</td>
# <td class="two td_left" data-th="First Name">ALRUEKIA</td>
# <td class="two td_left" data-th="Middle Name">ROCHELLE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">JEFFERSON CITY</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=30712&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BROWNE</td>
# <td class="one td_left" data-th="First Name">ALBERT</td>
# <td class="one td_left" data-th="Middle Name">HARVEY</td>
# <td class="one td_left" data-th="Suffix">II</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">29</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3089&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BROWNLEE</td>
# <td class="two td_left" data-th="First Name">LARRY</td>
# <td class="two td_left" data-th="Middle Name">KEVIN</td>
# <td class="two td_left" data-th="Suffix">JR</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">26</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5390&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BURKS-MATHENY</td>
# <td class="one td_left" data-th="First Name">NOAH</td>
# <td class="one td_left" data-th="Middle Name">CHRISTIANSON</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">22</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1688&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BUTLER</td>
# <td class="two td_left" data-th="First Name">ALBERT</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">39</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6649&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CARTER</td>
# <td class="one td_left" data-th="First Name">DEWAYNE</td>
# <td class="one td_left" data-th="Middle Name">THEODORE</td>
# <td class="one td_left" data-th="Suffix">J</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">29</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=15691&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CHAIRSE-MCCUTCHEON</td>
# <td class="two td_left" data-th="First Name">AHMAD</td>
# <td class="two td_left" data-th="Middle Name"> </td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">22</td>
# <td class="two td_left" data-th="City">FAYETTE</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=29511&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CHEATOM</td>
# <td class="one td_left" data-th="First Name">DARIEN</td>
# <td class="one td_left" data-th="Middle Name">CAPRI</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">27</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=27632&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CHEN</td>
# <td class="two td_left" data-th="First Name">DENGCHENG</td>
# <td class="two td_left" data-th="Middle Name"> </td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">A</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=46&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CHILEL-MORALES</td>
# <td class="one td_left" data-th="First Name">ALVARO</td>
# <td class="one td_left" data-th="Middle Name">GILBERTO</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">U</td>
# <td class="one td_right" data-th="Age">31</td>
# <td class="one td_left" data-th="City">SIOUX CENTER</td>
# <td class="one td_left" data-th="State">IA</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=17980&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CLAYTON</td>
# <td class="two td_left" data-th="First Name">SHANE</td>
# <td class="two td_left" data-th="Middle Name">MICHAIL</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">32</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=17487&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COIL</td>
# <td class="one td_left" data-th="First Name">RYAN</td>
# <td class="one td_left" data-th="Middle Name">WAYNE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">33</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1278&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COLLINS</td>
# <td class="two td_left" data-th="First Name">RENEE</td>
# <td class="two td_left" data-th="Middle Name">MICHELLE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">51</td>
# <td class="two td_left" data-th="City">ROCHEPORT</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=47&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COMFORT</td>
# <td class="one td_left" data-th="First Name">KEITH</td>
# <td class="one td_left" data-th="Middle Name">ALAN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">39</td>
# <td class="one td_left" data-th="City">LAKE GENEVA</td>
# <td class="one td_left" data-th="State">WI</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=67&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CONN</td>
# <td class="two td_left" data-th="First Name">MARK</td>
# <td class="two td_left" data-th="Middle Name">ALLEN</td>
# <td class="two td_left" data-th="Suffix">JR</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">28</td>
# <td class="two td_left" data-th="City">JEFFERSON CITY</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2953&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COOK</td>
# <td class="one td_left" data-th="First Name">CHRIS</td>
# <td class="one td_left" data-th="Middle Name">ALAN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">54</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=4702&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">COOPER</td>
# <td class="two td_left" data-th="First Name">TRE`</td>
# <td class="two td_left" data-th="Middle Name">LAMONT</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">28</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=9246&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">COWANS</td>
# <td class="one td_left" data-th="First Name">LATOYA</td>
# <td class="one td_left" data-th="Middle Name">XAVIERASIERA</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">30</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=15822&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CRAFT</td>
# <td class="two td_left" data-th="First Name">HOWARD</td>
# <td class="two td_left" data-th="Middle Name">EARL</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">20</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2149&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CRAFT</td>
# <td class="one td_left" data-th="First Name">TYRESE</td>
# <td class="one td_left" data-th="Middle Name">RAY</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">17</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=28844&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CRAWFORD</td>
# <td class="two td_left" data-th="First Name">SHANE</td>
# <td class="two td_left" data-th="Middle Name">EDWARD</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">33</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3737&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">CREASON</td>
# <td class="one td_left" data-th="First Name">AUSTIN</td>
# <td class="one td_left" data-th="Middle Name">WADE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">25</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6829&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CRUM</td>
# <td class="two td_left" data-th="First Name">MICHAEL</td>
# <td class="two td_left" data-th="Middle Name">BENJAMIN</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">23</td>
# <td class="two td_left" data-th="City">AUXVASSE</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6850&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">DANCY</td>
# <td class="one td_left" data-th="First Name">JARVIS</td>
# <td class="one td_left" data-th="Middle Name">MONTELL</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">29</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=8078&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">DARBY</td>
# <td class="two td_left" data-th="First Name">SCOTT</td>
# <td class="two td_left" data-th="Middle Name">WAYNE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">43</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=14228&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="tr-paging">
# <th class="th_left paging_row bottomPaging" colspan="93">  Detainee Count: 259
#                     <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
# <ul>
# <li>
# <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)"><i class="fa fa-angle-double-left fa-large"> </i></a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)"><i class="fa fa-angle-left fa-large"> </i></a>
# </li>
# <li class="disabled">
# <a href="#">Page 1 of 6</a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)"><i class="fa fa-angle-right fa-large"> </i></a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)"><i class="fa fa-angle-double-right fa-large"> </i></a>
# </li>
# </ul>
# </div>
# </th>
# </tr>]

# %%
### Editing the code to fetch details of every record. The 'Case Number' and 'Charge Description' is Fetched for every Record.
list_of_rows = []
try:
    outfile = open("./inmates.csv", "w")  # create an empty file in write mode
    writer = csv.writer(outfile)
    
    # Add header to the file
    writer.writerow(["Last", "First", "Middle", "Gender", "Race", "Age", "City", "State","Case Number","Charge Description"])
    for row in table.findAll('tr'):  # Get all the table rows and each row get the values.
        list_of_cells = []
        for cell in row.findAll("td"):
            if(cell['data-th'] == ''):
                continue
            text = cell.text.replace('&nbsp;', '')   # nbsp - non breaking space
            list_of_cells.append(text)
        for anchor in row.findAll('a'):
            #href is fetched for every record and the response is parsed for every individual hit to href.
            details_href = "https://report.boonecountymo.org/mrcjava/servlet/"+anchor['href']
            details_response = requests.get(details_href)
            details_html = details_response.content
            details_soup = BeautifulSoup(details_html, "lxml")
            details_table = details_soup.find('tbody', attrs={'class': 'stripe'})
            if details_table is not None:
                details_table_tr = details_table.find('tr', attrs={"class": "detailBackground"})
                if details_table_tr is not None:
                    list_of_cells.append((details_table_tr.find('td', attrs = {'data-th' : 'CASE #'})).text)
                    list_of_cells.append((details_table_tr.find('td', attrs = {'data-th' : 'CHARGE DESCRIPTION'})).text)
        arrLength = len(list_of_cells)
        writer.writerow(list_of_cells)
finally:
    outfile.close()

# %%
# data cleaning 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./inmates.csv')
df.head()
# Out:
#        Last     First   Middle Gender Race Age  City      State Case Number  \
# 0     ADAMS     LACEE  KABRINA           F   B    25  ARMSTRONG          MO
# 1      AKES   MELANIE    LEIGH           F   W    38   COLUMBIA          MO
# 2  ARMSTEAD  AUGUSTUS   ADOLPH     JR    M   B    32   COLUMBIA          MO
# 3  AUNGERER      MARK  CHARLES           M   W    54   COLUMBIA          MO
# 4     AYERS    DANIEL  DASHAWN           M   B    18   COLUMBIA          MO
#
#    Charge Description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Drop certain fields if they are not relevant for analysis
df.drop(['Race'], inplace=True, axis=1)
df.head()
# Out:
#        Last     First   Middle Gender Age  City      State Case Number  \
# 0     ADAMS     LACEE  KABRINA          B    25  ARMSTRONG          MO
# 1      AKES   MELANIE    LEIGH          W    38   COLUMBIA          MO
# 2  ARMSTEAD  AUGUSTUS   ADOLPH     JR   B    32   COLUMBIA          MO
# 3  AUNGERER      MARK  CHARLES          W    54   COLUMBIA          MO
# 4     AYERS    DANIEL  DASHAWN          B    18   COLUMBIA          MO
#
#    Charge Description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Expanding M as Male and F as Female.
gender = df['Gender']
male = gender.str.contains('M')
female = gender.str.contains('F')
df['Gender'] = np.where(male, 'Male',
                       np.where(female, 'Female',
                               gender))
df.head()
# Out:
#        Last     First   Middle Gender Age  City      State Case Number  \
# 0     ADAMS     LACEE  KABRINA          B    25  ARMSTRONG          MO
# 1      AKES   MELANIE    LEIGH          W    38   COLUMBIA          MO
# 2  ARMSTEAD  AUGUSTUS   ADOLPH     JR   B    32   COLUMBIA          MO
# 3  AUNGERER      MARK  CHARLES          W    54   COLUMBIA          MO
# 4     AYERS    DANIEL  DASHAWN          B    18   COLUMBIA          MO
#
#    Charge Description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Check for missing values in Case Number
df['Case Number'].isnull().values.any()
# Out:
# False

# %%
# Fill In missing values with a default value
df['Case Number'].fillna("No Case Number Available", inplace=True)
df['Charge Description'].fillna("No Description Available", inplace=True)
df.head()
# Out:
#        Last     First   Middle Gender Age  City      State Case Number  \
# 0     ADAMS     LACEE  KABRINA          B    25  ARMSTRONG          MO
# 1      AKES   MELANIE    LEIGH          W    38   COLUMBIA          MO
# 2  ARMSTEAD  AUGUSTUS   ADOLPH     JR   B    32   COLUMBIA          MO
# 3  AUNGERER      MARK  CHARLES          W    54   COLUMBIA          MO
# 4     AYERS    DANIEL  DASHAWN          B    18   COLUMBIA          MO
#
#          Charge Description
# 0  No Description Available
# 1  No Description Available
# 2  No Description Available
# 3  No Description Available
# 4  No Description Available

# %%
# Remove whitespaces from Charge description and changing to uppercase
df['Charge Description'] = df['Charge Description'].str.strip()
df['Charge Description'] = df['Charge Description'].str.upper()
df.head()
# Out:
#        Last     First   Middle Gender Age  City      State Case Number  \
# 0     ADAMS     LACEE  KABRINA          B    25  ARMSTRONG          MO
# 1      AKES   MELANIE    LEIGH          W    38   COLUMBIA          MO
# 2  ARMSTEAD  AUGUSTUS   ADOLPH     JR   B    32   COLUMBIA          MO
# 3  AUNGERER      MARK  CHARLES          W    54   COLUMBIA          MO
# 4     AYERS    DANIEL  DASHAWN          B    18   COLUMBIA          MO
#
#          Charge Description
# 0  NO DESCRIPTION AVAILABLE
# 1  NO DESCRIPTION AVAILABLE
# 2  NO DESCRIPTION AVAILABLE
# 3  NO DESCRIPTION AVAILABLE
# 4  NO DESCRIPTION AVAILABLE

# %%
# save final results
df.to_csv("./cleaninmates.csv")
