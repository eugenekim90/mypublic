# %%
# !pip install keras
# !pip install tensorflow


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Activation
# other imports as needed


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation
# from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
import datetime
# Out:
# Requirement already satisfied: keras in c:\users\eugen\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow in c:\users\eugen\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\eugen\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\eugen\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.28.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\eugen\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\eugen\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\eugen\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\eugen\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\eugen\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\eugen\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\eugen\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\eugen\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eugen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eugen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eugen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eugen\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\eugen\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\eugen\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\eugen\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# WARNING:tensorflow:From C:\Users\eugen\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Out:
# C:\Users\eugen\Downloads

# %%
import os
print(os.getcwd())
os.chdir('C:/Users/eugen/')

# %%
# Load dataset
data_qqq = pd.read_csv('dataset/QQQ.csv')

# %%
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
data_qqq.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2014-02-19  90.080002  90.290001  89.449997  89.629997  82.181267  41749900
# 1  2014-02-20  89.690002  90.220001  89.309998  90.050003  82.566376  41814800
# 2  2014-02-21  90.339996  90.470001  89.820000  89.930000  82.456345  31192200
# 3  2014-02-24  90.139999  90.820000  90.040001  90.410004  82.896423  31500400
# 4  2014-02-25  90.540001  90.720001  90.019997  90.309998  82.804726  26771700

# %%
len(data_qqq)
# Out:
# 2517

# %%
data_vix = pd.read_csv('dataset/vix.csv')

# %%
data_vix.head()
len(data_vix)
# Out:
# 2608

# %%
merged_data = pd.merge(data_qqq, data_vix, on='Date', how='inner')

# %%
data=merged_data

# %%
data.head()
# Out:
#          Date     Open_x     High_x      Low_x    Close_x  Adj Close_x  \
# 0  2014-02-19  90.080002  90.290001  89.449997  89.629997    82.181267
# 1  2014-02-20  89.690002  90.220001  89.309998  90.050003    82.566376
# 2  2014-02-21  90.339996  90.470001  89.820000  89.930000    82.456345
# 3  2014-02-24  90.139999  90.820000  90.040001  90.410004    82.896423
# 4  2014-02-25  90.540001  90.720001  90.019997  90.309998    82.804726
#
#    Volume_x  Open_y  High_y  Low_y  Close_y  Adj Close_y  Volume_y
# 0  41749900   14.85   15.73  14.12    15.50        15.50       0.0
# 1  41814800   15.28   15.80  14.59    14.79        14.79       0.0
# 2  31192200   14.74   14.79  14.19    14.68        14.68       0.0
# 3  31500400   14.83   14.83  13.97    14.23        14.23       0.0
# 4  26771700   14.17   14.83  13.66    13.67        13.67       0.0

# %%
# Calculate mean price for qqq
high_prices = data['High_x'].values
low_prices = data['Low_x'].values
mid_prices = (high_prices + low_prices) / 2

# %%
# Use VIX and Volume
high_VIX = data['High_y'].values
low_VIX = data['Low_y'].values

vix = (high_prices + low_prices) / 2
volumes = data['Volume_x'].values

# %%
# Combine all features into one matrix
features = np.column_stack((mid_prices, vix, volumes))

# %%
# Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)

# %%
# Prepare the dataset for training
seq_len = 50
result = []
for index in range(len(scaled_features) - seq_len):
    result.append(scaled_features[index: index + seq_len + 1])

result = np.array(result)

# %%
# Split train and test data
row = int(round(0.9 * result.shape[0]))
train = result[:row, :]
np.random.shuffle(train)

x_train = train[:, :-1]
y_train = train[:, -1][:,1]  # Assuming the second feature is the closing price you want to predict

x_test = result[row:, :-1]
y_test = result[row:, -1][:,1]

# Reshape data for LSTM layer
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 3))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 3))

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(seq_len, 3)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='rmsprop')
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\eugen\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\eugen\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10800
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 40305 (157.44 KB)
# Trainable params: 40305 (157.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=10, epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\eugen\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 222/222 [==============================] - 6s 15ms/step - loss: 0.0030 - val_loss: 0.0014
# Epoch 2/20
# 222/222 [==============================] - 3s 13ms/step - loss: 8.2762e-04 - val_loss: 0.0031
# Epoch 3/20
# 222/222 [==============================] - 3s 14ms/step - loss: 6.4628e-04 - val_loss: 5.5789e-04
# Epoch 4/20
# 222/222 [==============================] - 3s 12ms/step - loss: 5.2982e-04 - val_loss: 3.7800e-04
# Epoch 5/20
# 222/222 [==============================] - 3s 12ms/step - loss: 4.6872e-04 - val_loss: 0.0084
# Epoch 6/20
# 222/222 [==============================] - 3s 12ms/step - loss: 4.3183e-04 - val_loss: 0.0049
# Epoch 7/20
# 222/222 [==============================] - 3s 12ms/step - loss: 3.7903e-04 - val_loss: 5.9623e-04
# Epoch 8/20
# 222/222 [==============================] - 3s 12ms/step - loss: 3.6741e-04 - val_loss: 3.5487e-04
# Epoch 9/20
# 222/222 [==============================] - 3s 15ms/step - loss: 3.3513e-04 - val_loss: 0.0016
# Epoch 10/20
# 222/222 [==============================] - 3s 12ms/step - loss: 3.2628e-04 - val_loss: 0.0010
# Epoch 11/20
# 222/222 [==============================] - 3s 13ms/step - loss: 3.2129e-04 - val_loss: 3.3541e-04
# Epoch 12/20
# 222/222 [==============================] - 3s 12ms/step - loss: 2.9927e-04 - val_loss: 8.7010e-04
# Epoch 13/20
# 222/222 [==============================] - 3s 12ms/step - loss: 2.7084e-04 - val_loss: 2.6103e-04
# Epoch 14/20
# 222/222 [==============================] - 3s 13ms/step - loss: 2.5066e-04 - val_loss: 9.4614e-04
# Epoch 15/20
# 222/222 [==============================] - 3s 13ms/step - loss: 2.5455e-04 - val_loss: 2.5438e-04
# Epoch 16/20
# 222/222 [==============================] - 3s 12ms/step - loss: 2.3917e-04 - val_loss: 2.5730e-04
# Epoch 17/20
# 222/222 [==============================] - 3s 12ms/step - loss: 2.3802e-04 - val_loss: 3.1912e-04
# Epoch 18/20
# 222/222 [==============================] - 3s 12ms/step - loss: 2.1376e-04 - val_loss: 4.4326e-04
# Epoch 19/20
# 222/222 [==============================] - 3s 14ms/step - loss: 2.0527e-04 - val_loss: 3.6158e-04
# Epoch 20/20
# 222/222 [==============================] - 3s 14ms/step - loss: 2.0698e-04 - val_loss: 2.2319e-04

# %%
# Make predictions
pred = model.predict(x_test)
# Out:
# 8/8 [==============================] - 1s 7ms/step

# %%
# Plotting
plt.figure(figsize=(20, 10))
plt.plot(y_test, label='True')
plt.plot(pred, label='Prediction')
plt.legend()
plt.show()

# %%
# Out:
# 1
