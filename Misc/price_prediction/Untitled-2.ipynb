# %%
#get the data from the polygon api
import requests     
import json
import csv
import datetime
import os
import time

url="https://api.polygon.io/v2/aggs/ticker/AMD/range/1000/second/2024-03-07/2024-03-08?adjusted=true&sort=asc&limit=50000&apiKey=I3jwnNbug0UkFs3G78dNjo2LNlI4Xu9G"

# %%
url="https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2023-01-09/2023-01-09?apiKey=I3jwnNbug0UkFs3G78dNjo2LNlI4Xu9G"

response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'ticker': 'AAPL',
#  'queryCount': 1,
#  'resultsCount': 1,
#  'adjusted': True,
#  'results': [{'v': 70790813.0,
#    'vw': 131.6292,
#    'o': 130.465,
#    'c': 130.15,
#    'h': 133.41,
#    'l': 129.89,
#    't': 1673240400000,
#    'n': 645365}],
#  'status': 'OK',
#  'request_id': '917f1ec553b980a2a5628123c3e207a1',
#  'count': 1}

# %%
data=requests.get("https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/minute/2024-03-07/2024-03-07?adjusted=true&sort=asc&limit=1000&apiKey=I3jwnNbug0UkFs3G78dNjo2LNlI4Xu9G").json()
import pandas as pd
df=pd.DataFrame(data['results'])
df

#change Unix time to date time
df['t']=pd.to_datetime(df['t'],unit='ms')
df
#drop outside of trading out
df=df[df['t'].dt.time.between(datetime.time(9,30),datetime.time(16,0))]
df
# Out:
#             v        vw         o         c       h       l  \
# 23      946.0  168.4953  168.5000  168.5000  168.50  168.50
# 24      737.0  168.5037  168.4900  168.4900  168.49  168.49
# 25     2065.0  168.3661  168.4500  168.3000  168.45  168.30
# 26     1822.0  168.3213  168.3300  168.3000  168.33  168.30
# 27     1893.0  168.2754  168.3000  168.2900  168.30  168.29
# ..        ...       ...       ...       ...     ...     ...
# 345  126666.0  168.6558  168.6800  168.6175  168.71  168.61
# 346  114040.0  168.6987  168.6267  168.7100  168.74  168.62
# 347  116052.0  168.7049  168.7100  168.6874  168.75  168.68
# 348  116936.0  168.7287  168.6885  168.7800  168.78  168.68
# 349  150011.0  168.7792  168.7750  168.7650  168.81  168.75
#
#                       t     n
# 23  2024-03-07 09:30:00    42
# 24  2024-03-07 09:31:00    27
# 25  2024-03-07 09:32:00    88
# 26  2024-03-07 09:34:00    29
# 27  2024-03-07 09:35:00    72
# ..                  ...   ...
# ...

# %%
import yfinance as yf


df=yf.download("AAPL",start="2024-03-07",end="2024-03-08", interval="1m")
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2024-03-07 09:30:00-05:00  169.149994  169.330002  168.669998  168.690002
# 2024-03-07 09:31:00-05:00  168.684998  168.924606  168.610001  168.720001
# 2024-03-07 09:32:00-05:00  168.720001  169.350006  168.679993  169.179993
# 2024-03-07 09:33:00-05:00  169.175995  169.629303  169.160004  169.380005
# 2024-03-07 09:34:00-05:00  169.369995  169.740005  169.360001  169.690002
# ...                               ...         ...         ...         ...
# 2024-03-07 15:55:00-05:00  169.270004  169.320007  169.160004  169.199997
# 2024-03-07 15:56:00-05:00  169.199997  169.229996  169.110001  169.119995
# 2024-03-07 15:57:00-05:00  169.115005  169.130005  168.899994  169.022507
# 2024-03-07 15:58:00-05:00  169.020004  169.100006  168.970001  169.095001
# 2024-03-07 15:59:00-05:00  169.095001  169.139999  168.949997  168.979996
#
# ...

# %%
data
# Out:
# [{'v': 70790813.0,
#   'vw': 131.6292,
#   'o': 130.465,
#   'c': 130.15,
#   'h': 133.41,
#   'l': 129.89,
#   't': 1673240400000,
#   'n': 645365},
#  {'v': 63896155.0,
#   'vw': 129.822,
#   'o': 130.26,
#   'c': 130.73,
#   'h': 131.2636,
#   'l': 128.12,
#   't': 1673326800000,
#   'n': 554940},
#  {'v': 69458949.0,
#   'vw': 132.3081,
#   'o': 131.25,
#   'c': 133.49,
#   'h': 133.51,
#   'l': 130.46,
#   't': 1673413200000,
#   'n': 561278},
#  {'v': 71379648.0,
#   'vw': 133.171,
#   'o': 133.88,
#   'c': 133.41,
#   'h': 134.26,
#   'l': 131.44,
#   't': 1673499600000,
#   'n': 635331},
#  {'v': 57809719.0,
#   'vw': 133.6773,
#   'o': 132.03,
#   'c': 134.76,
#   'h': 134.92,
#   'l': 131.66,
#   't': 1673586000000,
#   'n': 537385},
#  {'v': 63612627.0,
#   'vw': 135.7587,
#   'o': 134.83,
#   'c': 135.94,
#   'h': 137.29,
#   'l': 134.13,
#   't': 1673931600000,
#   'n': 595831},
#  {'v': 69672800.0,
#   'vw': 136.3316,
#   'o': 136.815,
#   'c': 135.21,
#   'h': 138.61,
# ...
